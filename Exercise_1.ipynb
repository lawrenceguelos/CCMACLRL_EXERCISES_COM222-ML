# %%
# !pip install pandas

# %%
import pandas as pd

# %%
dataframe = pd.read_excel("excel.xlsx")

# %%
dataframe
# Out:
#    Height(cm)  Weight (kg)  Age
# 0         177           70   20
# 1         176           68   19
# 2         175           66   18
# 3         173           60   17
# 4         170           56   16
# 5         163           50   15
# 6         156           45   14
# 7         149           39   13
# 8         143           35   12

# %%
dataframe.head()
# Out:
#    Height(cm)  Weight (kg)  Age
# 0         177           70   20
# 1         176           68   19
# 2         175           66   18
# 3         173           60   17
# 4         170           56   16

# %%
dataframe.tail()
# Out:
#    Height(cm)  Weight (kg)  Age
# 4         170           56   16
# 5         163           50   15
# 6         156           45   14
# 7         149           39   13
# 8         143           35   12

# %%
dataframe.value_counts()
# Out:
# Height(cm)  Weight (kg)  Age
# 143         35           12     1
# 149         39           13     1
# 156         45           14     1
# 163         50           15     1
# 170         56           16     1
# 173         60           17     1
# 175         66           18     1
# 176         68           19     1
# 177         70           20     1
# Name: count, dtype: int64

# %%
dataframe = pd.read_excel("excel.xlsx")

# %%
dataframe
# Out:
#    Height(cm)  Weight (kg)  Age
# 0         177           70   20
# 1         176           68   19
# 2         175           66   18
# 3         173           60   17
# 4         170           56   16
# 5         163           50   15
# 6         156           45   14
# 7         149           39   13
# 8         143           35   12
# 9         156           45   14

# %%
dataframe.value_counts()
# Out:
# Height(cm)  Weight (kg)  Age
# 156         45           14     2
# 143         35           12     1
# 149         39           13     1
# 163         50           15     1
# 170         56           16     1
# 173         60           17     1
# 175         66           18     1
# 176         68           19     1
# 177         70           20     1
# Name: count, dtype: int64

# %%
dataframe.drop_duplicates(inplace=True)

# %%
dataframe.value_counts()
# Out:
# Height(cm)  Weight (kg)  Age
# 143         35           12     1
# 149         39           13     1
# 156         45           14     1
# 163         50           15     1
# 170         56           16     1
# 173         60           17     1
# 175         66           18     1
# 176         68           19     1
# 177         70           20     1
# Name: count, dtype: int64

# %%
dataframe.iloc[0,]
# Out:
# Height(cm)     177
# Weight (kg)     70
# Age             20
# Name: 0, dtype: int64

# %%
dataframe.describe()
# Out:
#        Height(cm)  Weight (kg)        Age
# count    9.000000     9.000000   9.000000
# mean   164.666667    54.333333  16.000000
# std     12.639225    12.835498   2.738613
# min    143.000000    35.000000  12.000000
# 25%    156.000000    45.000000  14.000000
# 50%    170.000000    56.000000  16.000000
# 75%    175.000000    66.000000  18.000000
# max    177.000000    70.000000  20.000000

# %%
dataframe.shape
# Out:
# (9, 3)

# %%
dataframe.drop(columns=["Age"], inplace=True)

# %%
dataframe
# Out:
#    Height(cm)  Weight (kg)
# 0         177           70
# 1         176           68
# 2         175           66
# 3         173           60
# 4         170           56
# 5         163           50
# 6         156           45
# 7         149           39
# 8         143           35

# %% [markdown]
# ##maplotlib

# %%
pip install matplotlib

# %%
from matplotlib import pyplot as plt

# %%
X = [1,2,3,4,5]
Y = [6,7,8,9,10]

plt.plot(X,Y,marker = 'o', color = 'blue', linestyle = 'dotted')
plt.grid()
plt.show()

# %%
dataframe
# Out:
#    Height(cm)  Weight (kg)
# 0         177           70
# 1         176           68
# 2         175           66
# 3         173           60
# 4         170           56
# 5         163           50
# 6         156           45
# 7         149           39
# 8         143           35

# %%
X = [1,2,3,4,5]
Y = [6,7,8,9,10]

plt.plot(dataframe['Height(cm)'], dataframe['Weight(kg)'], marker = 'o', color = 'blue', linestyle = 'dotted')
plt.title("My plot")
plt.xlabel("Height")
plt.ylabel("Weight")
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Weight(kg)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-76788f3f57ac> in <cell line: 4>()
#       2 Y = [6,7,8,9,10]
#       3
# ...
